# %% [markdown]
# <a href="https://colab.research.google.com/github/scbadkas19/NLP/blob/master/cl5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import gensim
import gzip
import nltk
from gensim.models import Word2Vec
from nltk import word_tokenize

from nltk.corpus import stopwords

# %%
data=pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz",lines=True)

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~''' #Function to remove punctuations
def punct_remover(str):
  no_punct = ""
  for char in str:
    if char not in punctuations:
      no_punct = no_punct + char
  return no_punct

# %%
def stopwords_remover(text): #Tokenizing text and removing the stop words
  text=text.lower()
  tokens=word_tokenize(text)
  nostop=[words for words in tokens if not words in stop_words]
  return nostop

# %%
data['reviewText']=data['reviewText'].apply(punct_remover)

# %%
data['revtxt_nostop_tokens']=data['reviewText'].apply(stopwords_remover)

# %%
def unique_tokens(text):
  unique_list=[]
  for words in text:
    if words not in unique_list:
      unique_list.append(words)
  return unique_list

# %%
data['revtxt_unique_tokens']=data['revtxt_nostop_tokens'].apply(unique_tokens)

# %%
data.head()
# Out:
#        reviewerID  ...                               revtxt_unique_tokens
# 0  A32T2H8150OJLU  ...  [bought, first, hp12c, 1984, served, faithfull...
# 1  A3MAFS04ZABRGO  ...  [belated, review, feel, obliged, share, views,...
# 2  A1F1A0QQP2XVH5  ...  [hp, 48gx, kicking, twenty, years, 11, 25, old...
# 3   A49R5DBXXQDE5  ...  [ive, started, finance, stuff, recently, went,...
# 4  A2XRMQA6PJ5ZJ8  ...  [simple, calculations, discounted, cash, flows...
#
# [5 rows x 11 columns]

# %%
wordlist=[[word] for word in data['revtxt_nostop_tokens'][0]]

# %%
wordlist
# Out:
# [['bought'],
#  ['first'],
#  ['hp12c'],
#  ['1984'],
#  ['served'],
#  ['faithfully'],
#  ['2002'],
#  ['lost'],
#  ['travelling'],
#  ['searched'],
#  ['another'],
#  ['one'],
#  ['replace'],
#  ['found'],
#  ['one'],
#  ['difficult'],
#  ['come'],
#  ['area'],
#  ['decided'],
#  ['buy'],
#  ['purchased'],
#  ['hp'],
#  ['49g'],
#  ['mistake'],
#  ['know'],
#  ['many'],
#  ['people'],
#  ['view'],
#  ['hp'],
#  ['49g'],
#  ['49g+'],
#  ['flagship'],
#  ['hp'],
#  ['line'],
#  ['disasterthe'],
#  ['49g'],
#  ['may'],
#  ['powerful'],
#  ['using'],
#  ['extremely'],
#  ['counterintuitiveand'],
#  ['manual'],
#  ['sketchy'],
#  ['best'],
#  ['12c'],
#  ['hand'],
#  ['need'],
#  ['way'],
#  ['makes'],
#  ['good'],
#  ['sense'],
#  ['meif'],
#  ['looking'],
#  ['solid'],
#  ['reliable'],
#  ['calculator'],
#  ['hp12c'],
#  ['may'],
#  ['programmable'],
#  ['basic'],
#  ['statistics'],
#  ['well'],
#  ['many'],
#  ['business'],
#  ['applications'],
#  ['manual'],
#  ['makes'],
#  ['sense'],
#  ['running'],
#  ['short'],
#  ['orderim'],
#  ['ready'],
#  ['set'],
#  ['49g'],
#  ['aside'],
#  ['move'],
#  ['back'],
#  ['old'],
#  ['friend'],
#  ['didnt'],
#  ['even'],
#  ['replace'],
#  ['batteries'],
#  ['well'],
#  ['decade'],
#  ['usehp'],
#  ['12c'],
#  ['im'],
#  ['coming'],
#  ['home']]

# %%
model=Word2Vec(wordlist, size=100, window=5, min_count=1, workers=4)

# %%
for i in wordlist:
  for j in wordlist:
    if j>i:
      print(i[0],' :',j[0],model.similarity(i[0],j[0]))
    else:
      continue
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# bought  : first -0.042358726
# bought  : hp12c 0.1104037
# bought  : served 0.009522279
# bought  : faithfully -0.091723755
# bought  : lost -0.1258794
# bought  : travelling -0.16259952
# bought  : searched 0.067011304
# bought  : one -0.05151549
# bought  : replace 0.045728102
# bought  : found -0.13148305
# bought  : one -0.05151549
# bought  : difficult 0.033007298
# bought  : come -0.15127271
# bought  : decided 0.1410057
# bought  : buy 0.20919159
# bought  : purchased -0.12006166
# bought  : hp -0.13987535
# bought  : mistake 0.049869146
# bought  : know 0.067196645
# bought  : many 0.047549307
# bought  : people 0.04710842
# bought  : view -0.07692989
# bought  : hp -0.13987535
# bought  : flagship -0.07475245
# bought  : hp -0.13987535
# bought  : line -0.064434655
# bought  : disasterthe -0.0031231819
# bought  : may -0.008887357
# bought  : powerful -0.16478904
# bought  : using 0.039052628
# bought  : extremely -0.15980648
# bought  : counterintuitiveand -0.13435833
# bought  : manual -0.03003129
# bought  : sketchy -0.08733557
# bought  : hand -0.054779667
# bought  : need -0.26078564
# bought  : way 0.02378784
# bought  : makes 0.0010877913
# bought  : good 0.01593412
# bought  : sense 0.015818305
# bought  : meif -0.13849886
# bought  : looking -0.0078038117
# bought  : solid 0.08716707
# bought  : reliable 0.21531406
# bought  : calculator 0.015589095
# bought  : hp12c 0.1104037
# bought  : may -0.008887357
# bought  : programmable 0.01952251
# bought  : statistics 0.11295227
# bought  : well -0.105494455
# bought  : many 0.047549307
# bought  : business 0.043321762
# bought  : manual -0.03003129
# bought  : makes 0.0010877913
# bought  : sense 0.015818305
# bought  : running 0.054834794
# bought  : short -0.06503355
# bought  : orderim -0.0012522523
# bought  : ready -0.0921709
# bought  : set 0.09422949
# bought  : move -0.103616506
# bought  : old 0.10641333
# bought  : friend -0.09717719
# bought  : didnt -0.18711174
# bought  : even -0.15310788
# bought  : replace 0.045728102
# bought  : well -0.105494455
# bought  : decade -0.043626055
# bought  : usehp -0.07973312
# bought  : im 0.12209317
# bought  : coming -0.13228165
# bought  : home -0.048280116
# first  : hp12c 0.047074668
# first  : served 0.036610242
# first  : lost 0.044707183
# first  : travelling -0.0058182376
# first  : searched -0.06394707
# first  : one 0.071073264
# first  : replace -0.014159248
# first  : found -0.24857028
# first  : one 0.071073264
# first  : purchased -0.006563952
# first  : hp -0.056187283
# first  : mistake 0.16538982
# first  : know -0.021369908
# first  : many -0.17260298
# first  : people 0.094755925
# first  : view -0.12108883
# first  : hp -0.056187283
# first  : flagship 0.12172139
# first  : hp -0.056187283
# first  : line 0.08869707
# first  : may 0.04446713
# first  : powerful -0.13437562
# first  : using 0.07283812
# first  : manual -0.27185994
# first  : sketchy -0.18462303
# first  : hand -0.13010602
# first  : need 0.22362043
# first  : way 0.12374222
# first  : makes 0.035902612
# first  : good 0.095433004
# first  : sense 0.18493019
# first  : meif -0.09962506
# first  : looking 0.048932828
# first  : solid 0.19174045
# first  : reliable -0.024195435
# first  : hp12c 0.047074668
# first  : may 0.04446713
# first  : programmable 0.1110194
# first  : statistics -0.093436934
# first  : well -0.07757182
# first  : many -0.17260298
# first  : manual -0.27185994
# first  : makes 0.035902612
# first  : sense 0.18493019
# first  : running 0.11497168
# first  : short -0.13931647
# first  : orderim -0.0070240917
# first  : ready 0.03543782
# first  : set -0.20535788
# first  : move -0.10464146
# first  : old -0.14127463
# first  : friend 0.10457119
# first  : replace -0.014159248
# first  : well -0.07757182
# first  : usehp -0.07501623
# first  : im 0.08630786
# first  : home -0.017809657
# hp12c  : served 0.033524167
# hp12c  : lost -0.06088351
# hp12c  : travelling -0.009186095
# hp12c  : searched 0.07837266
# hp12c  : one 0.040582966
# hp12c  : replace -0.067509584
# hp12c  : one 0.040582966
# hp12c  : purchased 0.21979548
# hp12c  : mistake -0.053983975
# hp12c  : know -0.020896327
# hp12c  : many 0.0029111733
# hp12c  : people -0.077877
# hp12c  : view -0.08104903
# hp12c  : line -0.18072046
# hp12c  : may -0.11348251
# hp12c  : powerful 0.084063925
# hp12c  : using 0.10468915
# hp12c  : manual -0.0018752797
# hp12c  : sketchy 0.006450222
# hp12c  : need -0.010705632
# hp12c  : way 0.030046044
# hp12c  : makes -0.0068686716
# hp12c  : sense 0.07143004
# hp12c  : meif -0.0056427475
# hp12c  : looking -0.012981661
# hp12c  : solid -0.09433873
# hp12c  : reliable -0.085250266
# hp12c  : may -0.11348251
# hp12c  : programmable 0.15836981
# hp12c  : statistics 0.07085844
# hp12c  : well -0.04433749
# hp12c  : many 0.0029111733
# hp12c  : manual -0.0018752797
# hp12c  : makes -0.0068686716
# hp12c  : sense 0.07143004
# hp12c  : running 0.08324576
# hp12c  : short 0.043323115
# hp12c  : orderim -0.038884193
# hp12c  : ready -0.07605015
# hp12c  : set 0.029074736
# hp12c  : move -0.017652169
# hp12c  : old 0.022225682
# hp12c  : replace -0.067509584
# hp12c  : well -0.04433749
# hp12c  : usehp -0.019974457
# hp12c  : im 0.02811361
# 1984  : bought -0.1803051
# 1984  : first -0.05827536
# 1984  : hp12c -0.06541167
# 1984  : served -0.054436754
# 1984  : faithfully 0.19468553
# 1984  : 2002 0.046635814
# 1984  : lost 0.04498631
# 1984  : travelling 0.143174
# 1984  : searched 0.13093513
# 1984  : another -0.10683569
# 1984  : one 0.04462685
# 1984  : replace 0.08241929
# 1984  : found 0.028071074
# 1984  : one 0.04462685
# 1984  : difficult -0.020204922
# 1984  : come -0.023736754
# 1984  : area -0.08730269
# 1984  : decided 0.03600556
# 1984  : buy -0.0398452
# 1984  : purchased -0.014065519
# 1984  : hp 0.1164482
# 1984  : 49g -0.007814515
# 1984  : mistake -0.10457448
# 1984  : know -0.06416561
# 1984  : many -0.08361731
# 1984  : people 0.029177397
# 1984  : view -0.016985767
# 1984  : hp 0.1164482
# 1984  : 49g -0.007814515
# 1984  : 49g+ 0.013891773
# 1984  : flagship 0.000642825
# 1984  : hp 0.1164482
# 1984  : line 0.039137628
# 1984  : disasterthe -0.11682067
# 1984  : 49g -0.007814515
# 1984  : may -0.11534052
# 1984  : powerful -0.046957195
# 1984  : using -0.054089405
# 1984  : extremely 0.12536153
# 1984  : counterintuitiveand 0.14775108
# 1984  : manual 0.031410247
# 1984  : sketchy 0.11590911
# 1984  : best -0.04757925
# 1984  : hand 0.011320371
# 1984  : need 0.0014975143
# 1984  : way -0.07596386
# 1984  : makes 0.22243021
# 1984  : good 0.12591606
# 1984  : sense -0.006294089
# 1984  : meif 0.004282887
# 1984  : looking 0.15600026
# 1984  : solid -0.018570527
# 1984  : reliable -0.074279256
# 1984  : calculator -0.12721898
# 1984  : hp12c -0.06541167
# 1984  : may -0.11534052
# 1984  : programmable 0.14754131
# 1984  : basic -0.032411154
# 1984  : statistics -0.12801844
# 1984  : well 0.013420635
# 1984  : many -0.08361731
# 1984  : business -0.17350093
# 1984  : applications 0.07460087
# 1984  : manual 0.031410247
# 1984  : makes 0.22243021
# 1984  : sense -0.006294089
# 1984  : running 0.05977469
# 1984  : short -0.1208394
# 1984  : orderim -0.0036103518
# 1984  : ready 0.21696247
# 1984  : set -0.070595846
# 1984  : 49g -0.007814515
# 1984  : aside -0.039943647
# 1984  : move -0.098594844
# 1984  : back 0.0198243
# 1984  : old 0.1801658
# 1984  : friend 0.11895445
# 1984  : didnt -0.12381292
# 1984  : even 0.06655407
# 1984  : replace 0.08241929
# 1984  : batteries -0.08761741
# 1984  : well 0.013420635
# 1984  : decade -0.24713881
# 1984  : usehp 0.14304943
# 1984  : im -0.05444345
# 1984  : coming -0.033815656
# 1984  : home -0.060237363
# served  : travelling 0.006795076
# served  : view 0.05630899
# served  : using -0.10116859
# served  : sketchy -0.0053643803
# served  : way 0.042486407
# served  : solid 0.19163077
# served  : statistics 0.10147473
# served  : well -0.111758284
# served  : short -0.33312207
# served  : set -0.20256446
# served  : well -0.111758284
# served  : usehp 0.194338
# faithfully  : first -0.081916265
# faithfully  : hp12c -0.05849259
# faithfully  : served 0.02398204
# faithfully  : lost 0.018203534
# faithfully  : travelling 0.10911216
# faithfully  : searched -0.1034215
# faithfully  : one 0.054298908
# faithfully  : replace -0.0026185955
# faithfully  : found -0.009539949
# faithfully  : one 0.054298908
# faithfully  : purchased -0.13915177
# faithfully  : hp 0.10471038
# faithfully  : mistake -0.0911432
# faithfully  : know -0.0026867369
# faithfully  : many -0.023150645
# faithfully  : people -0.1117394
# faithfully  : view -0.107791886
# faithfully  : hp 0.10471038
# faithfully  : flagship -0.060964018
# faithfully  : hp 0.10471038
# faithfully  : line 0.038201112
# faithfully  : may -0.006212325
# faithfully  : powerful -0.026100932
# faithfully  : using 0.02856699
# faithfully  : manual 0.034636825
# faithfully  : sketchy 0.02257292
# faithfully  : hand -0.029666688
# faithfully  : need -0.1368038
# faithfully  : way -0.0019279476
# faithfully  : makes 0.020867972
# faithfully  : good -0.038606793
# faithfully  : sense 0.114457
# faithfully  : meif -0.09753432
# faithfully  : looking 0.050206862
# faithfully  : solid -0.05936863
# faithfully  : reliable -0.095404
# faithfully  : hp12c -0.05849259
# faithfully  : may -0.006212325
# faithfully  : programmable -0.05579685
# faithfully  : statistics -0.04664176
# faithfully  : well 0.107072584
# faithfully  : many -0.023150645
# faithfully  : manual 0.034636825
# faithfully  : makes 0.020867972
# faithfully  : sense 0.114457
# faithfully  : running 0.097639546
# faithfully  : short -0.10897642
# faithfully  : orderim 0.14474808
# faithfully  : ready 0.10830718
# faithfully  : set -0.1853329
# faithfully  : move 0.099370934
# faithfully  : old -0.003718646
# faithfully  : friend -0.009582001
# faithfully  : replace -0.0026185955
# faithfully  : well 0.107072584
# faithfully  : usehp -0.003885033
# faithfully  : im 0.15645391
# faithfully  : home -0.03372189
# 2002  : bought 0.019155763
# 2002  : first -0.05443893
# 2002  : hp12c -0.066518985
# 2002  : served 0.11875082
# 2002  : faithfully 0.039174657
# 2002  : lost 0.09078577
# 2002  : travelling 0.08439049
# 2002  : searched 0.13350245
# 2002  : another -0.021387553
# 2002  : one 0.011056185
# 2002  : replace 0.094636366
# 2002  : found 0.20707
# 2002  : one 0.011056185
# 2002  : difficult 0.025860509
# 2002  : come -0.05145899
# 2002  : area 0.12980528
# 2002  : decided -0.018513551
# 2002  : buy 0.042656228
# 2002  : purchased -0.09863801
# 2002  : hp 0.026518608
# 2002  : 49g -0.114838175
# 2002  : mistake 0.17540787
# 2002  : know -0.081502594
# 2002  : many -0.07686322
# 2002  : people -0.047309324
# 2002  : view -0.12499846
# 2002  : hp 0.026518608
# 2002  : 49g -0.114838175
# 2002  : 49g+ 0.0557493
# 2002  : flagship 0.07162323
# 2002  : hp 0.026518608
# 2002  : line 0.124190524
# 2002  : disasterthe -0.02631188
# 2002  : 49g -0.114838175
# 2002  : may 0.003828561
# 2002  : powerful -0.15002692
# 2002  : using 0.06908188
# 2002  : extremely -0.06745182
# 2002  : counterintuitiveand -0.16998054
# 2002  : manual -0.07073245
# 2002  : sketchy -0.116496325
# 2002  : best -0.107540146
# 2002  : hand -0.09520376
# 2002  : need 0.0011138192
# 2002  : way 0.013257981
# 2002  : makes 0.07428262
# 2002  : good 0.0002559803
# 2002  : sense -0.10741063
# 2002  : meif -0.07646497
# 2002  : looking 0.04643347
# 2002  : solid -0.16032916
# 2002  : reliable 0.003346345
# 2002  : calculator -0.04451691
# 2002  : hp12c -0.066518985
# 2002  : may 0.003828561
# 2002  : programmable 0.022078848
# 2002  : basic 0.12917714
# 2002  : statistics 0.045780413
# 2002  : well -0.1736431
# 2002  : many -0.07686322
# 2002  : business 0.1633928
# 2002  : applications 0.110769816
# 2002  : manual -0.07073245
# 2002  : makes 0.07428262
# 2002  : sense -0.10741063
# 2002  : running 0.08996614
# 2002  : short -0.097388536
# 2002  : orderim -0.06575135
# 2002  : ready -0.01632524
# 2002  : set 0.06495088
# 2002  : 49g -0.114838175
# 2002  : aside 0.1585229
# 2002  : move -0.096976906
# 2002  : back -0.051219
# 2002  : old 0.014822254
# 2002  : friend -0.0055692354
# 2002  : didnt -0.13175516
# 2002  : even -0.16401403
# 2002  : replace 0.094636366
# 2002  : batteries 0.10745979
# 2002  : well -0.1736431
# 2002  : decade -0.1012452
# 2002  : usehp 0.099241935
# 2002  : im 0.024995137
# 2002  : coming 0.1541952
# 2002  : home -0.045436278
# lost  : served 0.1287557
# lost  : travelling -0.010086468
# lost  : searched 0.068657435
# lost  : one 0.032238744
# lost  : replace -0.10473913
# lost  : one 0.032238744
# lost  : purchased -0.0072559183
# lost  : mistake 0.057177592
# lost  : many 0.050742477
# lost  : people -0.041534487
# lost  : view -0.048248667
# lost  : may -0.14035836
# lost  : powerful -0.08627029
# lost  : using -0.23333918
# lost  : manual -0.010357375
# lost  : sketchy -0.054138467
# lost  : need 0.1747647
# lost  : way -0.043933462
# lost  : makes -0.022754729
# lost  : sense -0.21356116
# lost  : meif 0.036160734
# lost  : solid -0.041965235
# lost  : reliable 0.111762404
# lost  : may -0.14035836
# lost  : programmable 0.08185164
# lost  : statistics -0.10365391
# lost  : well 0.1949587
# lost  : many 0.050742477
# lost  : manual -0.010357375
# lost  : makes -0.022754729
# lost  : sense -0.21356116
# lost  : running -0.028654885
# lost  : short 0.071624026
# lost  : orderim -0.02808756
# lost  : ready 0.05324347
# lost  : set 0.027192868
# lost  : move -0.009756884
# lost  : old 0.12624727
# lost  : replace -0.10473913
# lost  : well 0.1949587
# lost  : usehp -0.0713586
# travelling  : view 0.045600526
# travelling  : using -0.036804847
# travelling  : way -0.20471446
# travelling  : well 0.16620922
# travelling  : well 0.16620922
# travelling  : usehp 0.031866822
# searched  : served 0.035876818
# searched  : travelling 0.14125906
# searched  : view 0.024696825
# searched  : using -0.014358249
# searched  : sketchy 0.009127071
# searched  : way -0.24443634
# searched  : sense -0.07756779
# searched  : solid -0.09630375
# searched  : statistics -0.02951512
# searched  : well 0.08025559
# searched  : sense -0.07756779
# searched  : short -0.016229752
# searched  : set 0.047180377
# searched  : well 0.08025559
# searched  : usehp 0.067741625
# another  : bought -0.09170892
# another  : first 0.03138053
# another  : hp12c -0.019455569
# another  : served 0.034326687
# another  : faithfully -0.03130772
# another  : lost 0.28281748
# another  : travelling 0.13471968
# another  : searched 0.015324591
# another  : one 0.13249348
# another  : replace 0.0031049973
# another  : found 0.0432056
# another  : one 0.13249348
# another  : difficult -0.005855598
# another  : come -0.035778012
# another  : area -0.15530367
# another  : decided 0.022574821
# another  : buy 0.014854546
# another  : purchased -0.067154914
# another  : hp 0.19859232
# another  : mistake -0.09515741
# another  : know -0.06392531
# another  : many 0.059308372
# another  : people 0.051426306
# another  : view 0.045241784
# another  : hp 0.19859232
# another  : flagship 0.011561581
# another  : hp 0.19859232
# another  : line 0.024119291
# another  : disasterthe 0.09571866
# another  : may -0.10835823
# another  : powerful 0.11997843
# another  : using -0.1422295
# another  : extremely 0.017144363
# another  : counterintuitiveand -0.17371476
# another  : manual 0.076289475
# another  : sketchy -0.037921026
# another  : best -0.10232159
# another  : hand -0.031749096
# another  : need 0.21302189
# another  : way -0.027215801
# another  : makes -0.045591865
# another  : good 0.02343436
# another  : sense -0.11132993
# another  : meif 0.08341987
# another  : looking 0.09583765
# another  : solid -0.15810284
# another  : reliable -0.02269876
# another  : calculator 0.026510032
# another  : hp12c -0.019455569
# another  : may -0.10835823
# another  : programmable 0.015085219
# another  : basic 0.15132636
# another  : statistics 0.03852185
# another  : well 0.0059088017
# another  : many 0.059308372
# another  : business -0.009823497
# another  : applications 0.05089939
# another  : manual 0.076289475
# another  : makes -0.045591865
# another  : sense -0.11132993
# another  : running -0.0863682
# another  : short -0.06806043
# another  : orderim -0.006556562
# another  : ready 0.1248992
# another  : set -0.08429504
# another  : aside -0.254503
# another  : move 0.06449415
# another  : back -0.0035568476
# another  : old 0.13512161
# another  : friend -0.1597891
# another  : didnt -0.004521923
# another  : even -0.03912562
# another  : replace 0.0031049973
# another  : batteries 0.104682826
# another  : well 0.0059088017
# another  : decade 0.17590067
# another  : usehp 0.07970165
# another  : im -0.045028344
# another  : coming -0.0026653344
# another  : home 0.101371124
# one  : served -0.022844186
# one  : travelling 0.1125677
# one  : searched 0.052432165
# one  : replace -0.015473305
# one  : purchased 0.026043957
# one  : people 0.055108503
# one  : view -0.06123537
# one  : powerful -0.002281244
# one  : using 0.0050767013
# one  : sketchy -0.093201675
# one  : way 0.073630325
# one  : sense 0.07554819
# one  : solid -0.19230737
# one  : reliable 0.004204062
# one  : programmable -0.15369329
# one  : statistics -0.09753525
# one  : well 0.16596329
# one  : sense 0.07554819
# one  : running -0.10458776
# one  : short 0.06619195
# one  : orderim 0.0074515855
# one  : ready 0.1378564
# one  : set -0.086572185
# one  : replace -0.015473305
# one  : well 0.16596329
# one  : usehp -0.04013767
# replace  : served 0.08113701
# replace  : travelling 0.04663511
# replace  : searched -0.12527125
# replace  : view -0.058068126
# replace  : using 0.021536885
# replace  : sketchy -0.03830632
# replace  : way 0.06584009
# replace  : sense -0.1963105
# replace  : solid 0.18227406
# replace  : statistics 0.0025862302
# replace  : well -0.025098061
# replace  : sense -0.1963105
# replace  : running -0.074493244
# replace  : short -0.10535399
# replace  : set -0.2971191
# replace  : well -0.025098061
# replace  : usehp 0.052261826
# found  : hp12c 0.10460913
# found  : served 0.18085107
# found  : lost 0.11642146
# found  : travelling 0.12974557
# found  : searched -0.13512668
# found  : one 0.08131461
# found  : replace -0.07653102
# found  : one 0.08131461
# found  : purchased -0.057348005
# found  : hp 0.08554777
# found  : mistake -0.09055876
# found  : know 0.038762458
# found  : many -0.030509215
# found  : people -0.09470802
# found  : view 0.07717149
# found  : hp 0.08554777
# found  : hp 0.08554777
# found  : line -0.045884684
# found  : may -0.06403603
# found  : powerful 0.07731222
# found  : using -0.11895981
# found  : manual 0.009103782
# found  : sketchy -0.026661564
# found  : hand -0.045093223
# found  : need -0.20593497
# found  : way -0.16031143
# found  : makes -0.10516562
# found  : good -0.066716574
# found  : sense -0.08793069
# found  : meif -0.0015579122
# found  : looking -0.077224754
# found  : solid -0.11330195
# found  : reliable 0.13796863
# found  : hp12c 0.10460913
# found  : may -0.06403603
# found  : programmable -0.13121589
# found  : statistics 0.12835608
# found  : well -0.11160624
# found  : many -0.030509215
# found  : manual 0.009103782
# found  : makes -0.10516562
# found  : sense -0.08793069
# found  : running -0.02083522
# found  : short -0.019675285
# found  : orderim -0.109677725
# found  : ready -0.16941282
# found  : set -0.04297197
# found  : move 0.0032713308
# found  : old -0.07995724
# found  : friend -0.0588601
# found  : replace -0.07653102
# found  : well -0.11160624
# found  : usehp 0.08983752
# found  : im -0.15468922
# found  : home -0.025957987
# one  : served -0.022844186
# one  : travelling 0.1125677
# one  : searched 0.052432165
# one  : replace -0.015473305
# one  : purchased 0.026043957
# one  : people 0.055108503
# one  : view -0.06123537
# one  : powerful -0.002281244
# one  : using 0.0050767013
# one  : sketchy -0.093201675
# one  : way 0.073630325
# one  : sense 0.07554819
# one  : solid -0.19230737
# one  : reliable 0.004204062
# one  : programmable -0.15369329
# one  : statistics -0.09753525
# one  : well 0.16596329
# one  : sense 0.07554819
# one  : running -0.10458776
# one  : short 0.06619195
# one  : orderim 0.0074515855
# one  : ready 0.1378564
# one  : set -0.086572185
# one  : replace -0.015473305
# one  : well 0.16596329
# one  : usehp -0.04013767
# difficult  : first -0.07864033
# difficult  : hp12c 0.15541467
# difficult  : served -0.046839893
# difficult  : faithfully -0.12742774
# difficult  : lost -0.029891465
# difficult  : travelling -0.12067961
# difficult  : searched -0.1103916
# difficult  : one -0.041507963
# difficult  : replace 0.051213525
# difficult  : found 0.032369483
# difficult  : one -0.041507963
# difficult  : purchased 0.060078423
# difficult  : hp -0.016348701
# difficult  : mistake -0.0017850492
# difficult  : know -0.0666282
# difficult  : many -0.018160006
# difficult  : people -0.057007685
# difficult  : view -0.019993799
# difficult  : hp -0.016348701
# difficult  : flagship 0.1269037
# difficult  : hp -0.016348701
# difficult  : line -0.12897718
# difficult  : disasterthe -0.06844567
# difficult  : may -0.15432785
# difficult  : powerful 0.026655093
# difficult  : using -0.050291408
# difficult  : extremely 0.007231494
# difficult  : manual -0.054333072
# difficult  : sketchy -0.01981981
# difficult  : hand 0.062431846
# difficult  : need -0.060408812
# difficult  : way -0.10948508
# difficult  : makes 0.04341432
# difficult  : good 0.0033545538
# difficult  : sense 0.09499024
# difficult  : meif 0.067062624
# difficult  : looking -0.026645549
# difficult  : solid -0.15391096
# difficult  : reliable -0.04521499
# difficult  : hp12c 0.15541467
# difficult  : may -0.15432785
# difficult  : programmable 0.10248602
# difficult  : statistics -0.026787916
# difficult  : well 0.03691437
# difficult  : many -0.018160006
# difficult  : manual -0.054333072
# difficult  : makes 0.04341432
# difficult  : sense 0.09499024
# difficult  : running -0.033845704
# difficult  : short -0.00044166343
# difficult  : orderim -0.14145698
# difficult  : ready -0.1786138
# difficult  : set 0.07542246
# difficult  : move 0.09700639
# difficult  : old -0.045962624
# difficult  : friend 0.07997315
# difficult  : even 0.11435152
# difficult  : replace 0.051213525
# difficult  : well 0.03691437
# difficult  : usehp -0.15567261
# difficult  : im -0.14670737
# difficult  : home -0.1740486
# come  : first 0.081954196
# come  : hp12c 0.06550057
# come  : served -0.020132095
# come  : faithfully -0.0748862
# come  : lost -0.03910952
# come  : travelling -0.09558026
# come  : searched -0.0034245513
# come  : one 0.23816817
# come  : replace -0.027976934
# come  : found -0.1143842
# come  : one 0.23816817
# come  : difficult 0.10802494
# come  : decided 0.10900567
# come  : purchased 0.09074242
# come  : hp 0.023304973
# come  : mistake -0.10243666
# come  : know -0.024766283
# come  : many -0.06667546
# come  : people -0.047802523
# come  : view -0.018223096
# come  : hp 0.023304973
# come  : flagship 0.10923511
# come  : hp 0.023304973
# come  : line 0.09442292
# come  : disasterthe -0.14763282
# come  : may -0.14962181
# come  : powerful -0.022645652
# come  : using 0.108223416
# come  : extremely 0.05157255
# come  : counterintuitiveand 0.045156937
# come  : manual 0.047275413
# come  : sketchy 0.110144466
# come  : hand 0.11109856
# come  : need -0.07291268
# come  : way 0.018905189
# come  : makes -0.040513813
# come  : good 0.12503195
# come  : sense 0.19389418
# come  : meif 0.009735167
# come  : looking -0.030123409
# come  : solid 0.031947307
# come  : reliable -0.06876806
# come  : hp12c 0.06550057
# come  : may -0.14962181
# come  : programmable 0.014459577
# come  : statistics -0.06113952
# come  : well 0.05694846
# come  : many -0.06667546
# come  : manual 0.047275413
# come  : makes -0.040513813
# come  : sense 0.19389418
# come  : running -0.18039773
# come  : short 0.00429534
# come  : orderim -0.107918054
# come  : ready 0.07605356
# come  : set -0.124519534
# come  : move 0.060438897
# come  : old -0.099814676
# come  : friend 0.11009046
# come  : didnt 0.25039148
# come  : even -0.028164923
# come  : replace -0.027976934
# come  : well 0.05694846
# come  : decade -0.049939826
# come  : usehp -0.05550202
# come  : im 0.037985567
# come  : coming -0.004958944
# come  : home 0.074607715
# area  : bought 0.054226425
# area  : first 0.102269225
# area  : hp12c 0.13903569
# area  : served 0.106581934
# area  : faithfully 0.099186756
# area  : lost -0.07915605
# area  : travelling -0.12911665
# area  : searched -0.02470398
# area  : one 0.041912057
# area  : replace 0.009727207
# area  : found 0.044723876
# area  : one 0.041912057
# area  : difficult 0.094896235
# area  : come 0.194049
# area  : decided 0.13776024
# area  : buy 0.08921708
# area  : purchased 0.070078254
# area  : hp -0.14240256
# area  : mistake 0.018366883
# area  : know -0.012404652
# area  : many -0.07814948
# area  : people -0.046731997
# area  : view -0.005344263
# area  : hp -0.14240256
# area  : flagship -0.031572785
# area  : hp -0.14240256
# area  : line 0.14697647
# area  : disasterthe -0.015797071
# area  : may -0.09559559
# area  : powerful -0.03141839
# area  : using 0.090383224
# area  : extremely -0.050485443
# area  : counterintuitiveand 0.015343456
# area  : manual 0.066998206
# area  : sketchy -0.06498243
# area  : best 0.1419721
# area  : hand -0.082901925
# area  : need -0.029469661
# area  : way 0.0138046555
# area  : makes 0.0037830977
# area  : good 0.02470675
# area  : sense 0.19376896
# area  : meif 0.03138758
# area  : looking -0.1698388
# area  : solid 0.114738755
# area  : reliable -0.042985693
# area  : calculator -0.15106092
# area  : hp12c 0.13903569
# area  : may -0.09559559
# area  : programmable 0.07254093
# area  : basic -0.09981705
# area  : statistics 0.033241197
# area  : well 0.01948837
# area  : many -0.07814948
# area  : business 0.058396123
# area  : manual 0.066998206
# area  : makes 0.0037830977
# area  : sense 0.19376896
# area  : running 0.0897383
# area  : short -0.05560196
# area  : orderim -0.10107382
# area  : ready -0.06412673
# area  : set -0.008427262
# area  : aside 0.09929906
# area  : move -0.037824966
# area  : back 0.0520201
# area  : old -0.098739944
# area  : friend 0.085537575
# area  : didnt -0.06651523
# area  : even -0.11505944
# area  : replace 0.009727207
# area  : batteries 0.040077876
# area  : well 0.01948837
# area  : decade -0.08812865
# area  : usehp -0.04585138
# area  : im 0.07849772
# area  : coming 0.06203033
# area  : home 0.007516744
# decided  : first -0.10216212
# decided  : hp12c 0.05317879
# decided  : served -0.032255255
# decided  : faithfully -0.046363145
# decided  : lost 0.08572393
# decided  : travelling -0.08678431
# decided  : searched -0.0031774226
# decided  : one -0.018678803
# decided  : replace -0.020344183
# decided  : found 0.058457907
# decided  : one -0.018678803
# decided  : difficult 0.2164744
# decided  : purchased 0.031601973
# decided  : hp 0.017920833
# decided  : mistake -0.041428465
# decided  : know -0.052679196
# decided  : many 0.042120107
# decided  : people -0.111837365
# decided  : view -0.0293466
# decided  : hp 0.017920833
# decided  : flagship 0.22486722
# decided  : hp 0.017920833
# decided  : line -0.050178874
# decided  : disasterthe 0.062126458
# decided  : may -0.015392577
# decided  : powerful 0.008047366
# decided  : using 0.03233689
# decided  : extremely -0.03311594
# decided  : manual 0.11138166
# decided  : sketchy -0.067498855
# decided  : hand -0.20194042
# decided  : need -0.0720029
# decided  : way 0.0033748904
# decided  : makes 0.07437791
# decided  : good -0.026957368
# decided  : sense 0.08706411
# decided  : meif 0.043387767
# decided  : looking -0.04602743
# decided  : solid -0.019696485
# decided  : reliable -0.06764628
# decided  : hp12c 0.05317879
# decided  : may -0.015392577
# decided  : programmable 0.2909095
# decided  : statistics 0.00035998132
# decided  : well 0.09757781
# decided  : many 0.042120107
# decided  : manual 0.11138166
# decided  : makes 0.07437791
# decided  : sense 0.08706411
# decided  : running 0.061154515
# decided  : short 0.030147728
# decided  : orderim -0.07903225
# decided  : ready -0.01818828
# decided  : set 0.06137542
# decided  : move -0.08893066
# decided  : old 0.06514976
# decided  : friend 0.11930181
# decided  : didnt 0.0014287789
# decided  : even -0.08426915
# decided  : replace -0.020344183
# decided  : well 0.09757781
# decided  : usehp 0.17742711
# decided  : im -0.15586111
# decided  : home -0.04143406
# buy  : first 0.015360032
# buy  : hp12c 0.048505932
# buy  : served -0.09983051
# buy  : faithfully 0.11874099
# buy  : lost -0.10741521
# buy  : travelling -0.08576078
# buy  : searched 0.10346812
# buy  : one 0.03091813
# buy  : replace -0.106674284
# buy  : found -0.17658335
# buy  : one 0.03091813
# buy  : difficult -0.15707368
# buy  : come -0.13811088
# buy  : decided -0.1696855
# buy  : purchased -0.12430192
# buy  : hp -0.10302523
# buy  : mistake -0.03823184
# buy  : know 0.14357315
# buy  : many -0.10568345
# buy  : people -0.093549244
# buy  : view -0.16521473
# buy  : hp -0.10302523
# buy  : flagship -0.33360386
# buy  : hp -0.10302523
# buy  : line 0.2462588
# buy  : disasterthe 0.01169663
# buy  : may 0.16445225
# buy  : powerful -0.10804028
# buy  : using 0.1442199
# buy  : extremely -0.0030513483
# buy  : counterintuitiveand -0.15217486
# buy  : manual 0.141841
# buy  : sketchy -0.032274112
# buy  : hand 0.021144774
# buy  : need -0.04203671
# buy  : way -0.016724357
# buy  : makes -0.10990746
# buy  : good -0.014998718
# buy  : sense -0.085346185
# buy  : meif -0.031774327
# buy  : looking 0.013224493
# buy  : solid 0.0024813954
# buy  : reliable 0.056824073
# buy  : calculator 0.013185686
# buy  : hp12c 0.048505932
# buy  : may 0.16445225
# buy  : programmable -0.10594157
# buy  : statistics 0.04491459
# buy  : well -0.002000267
# buy  : many -0.10568345
# buy  : manual 0.141841
# buy  : makes -0.10990746
# buy  : sense -0.085346185
# buy  : running 0.08508847
# buy  : short -0.021242995
# buy  : orderim 0.0833674
# buy  : ready 0.15052305
# buy  : set 0.073677294
# buy  : move 0.08968591
# buy  : old 0.08968014
# buy  : friend -0.032855056
# buy  : didnt -0.011675231
# buy  : even -0.093971044
# buy  : replace -0.106674284
# buy  : well -0.002000267
# buy  : decade -0.18075788
# buy  : usehp 0.021233808
# buy  : im 0.024970414
# buy  : coming -0.050509527
# buy  : home -0.012714872
# purchased  : served -0.06689878
# purchased  : travelling 0.17421085
# purchased  : searched 0.09485323
# purchased  : replace -0.15428643
# purchased  : view 0.0022862302
# purchased  : using -0.04459902
# purchased  : sketchy 0.1764194
# purchased  : way -0.12069684
# purchased  : sense 0.10905377
# purchased  : solid 0.04313492
# purchased  : reliable 0.085011594
# purchased  : statistics -0.114565566
# purchased  : well 0.17346267
# purchased  : sense 0.10905377
# purchased  : running 0.15248707
# purchased  : short 0.08065726
# purchased  : ready -0.00812639
# purchased  : set 0.006660122
# purchased  : replace -0.15428643
# purchased  : well 0.17346267
# purchased  : usehp 0.013875611
# hp  : hp12c -0.008879955
# hp  : served 0.08544172
# hp  : lost 0.13352613
# hp  : travelling 0.084382795
# hp  : searched -0.09823452
# hp  : one 0.1076088
# hp  : replace 0.022620272
# hp  : one 0.1076088
# hp  : purchased -0.03432066
# hp  : mistake -0.049593285
# hp  : know -0.09014127
# hp  : many 0.083381675
# hp  : people 0.0001655335
# hp  : view 0.194987
# hp  : line -0.17898433
# hp  : may -0.16258623
# hp  : powerful 0.16360411
# hp  : using -0.024117418
# hp  : manual -0.05510219
# hp  : sketchy -0.14434873
# hp  : need 0.06593702
# hp  : way -0.061705634
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : meif 0.110919
# hp  : looking 0.14833298
# hp  : solid -0.18124832
# hp  : reliable -0.0055697868
# hp  : hp12c -0.008879955
# hp  : may -0.16258623
# hp  : programmable -0.04159226
# hp  : statistics -0.12008675
# hp  : well 0.051083915
# hp  : many 0.083381675
# hp  : manual -0.05510219
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : running -0.058398593
# hp  : short -0.07616732
# hp  : orderim -0.009110292
# hp  : ready 0.018984461
# hp  : set -0.23088759
# hp  : move 0.024787236
# hp  : old 0.082955636
# hp  : replace 0.022620272
# hp  : well 0.051083915
# hp  : usehp 0.12764128
# hp  : im -0.006339741
# 49g  : bought 0.07399173
# 49g  : first -0.015214133
# 49g  : hp12c -0.12930831
# 49g  : served 0.0044194977
# 49g  : faithfully -0.2683381
# 49g  : lost 0.0113928225
# 49g  : travelling 0.10195126
# 49g  : searched -0.006931223
# 49g  : another -0.014278027
# 49g  : one 0.04712073
# 49g  : replace 0.027825532
# 49g  : found 0.022157108
# 49g  : one 0.04712073
# 49g  : difficult -0.06737784
# 49g  : come 0.04646948
# 49g  : area -0.08632576
# 49g  : decided 0.12307058
# 49g  : buy -0.19405155
# 49g  : purchased 0.10718884
# 49g  : hp -0.0489818
# 49g  : mistake 0.07722008
# 49g  : know 0.015188675
# 49g  : many -0.03577241
# 49g  : people 0.14722982
# 49g  : view 0.2315928
# 49g  : hp -0.0489818
# 49g  : 49g+ 0.028096301
# 49g  : flagship 0.024531052
# 49g  : hp -0.0489818
# 49g  : line -0.07527419
# 49g  : disasterthe 0.05984285
# 49g  : may 0.0067993854
# 49g  : powerful -0.03121867
# 49g  : using -0.064319
# 49g  : extremely 0.017212862
# 49g  : counterintuitiveand 0.080515094
# 49g  : manual 0.0011978501
# 49g  : sketchy -0.02019897
# 49g  : best 0.18098393
# 49g  : hand 0.08237483
# 49g  : need 0.10352261
# 49g  : way -0.08916335
# 49g  : makes 0.029490685
# 49g  : good -0.1504924
# 49g  : sense -0.13184506
# 49g  : meif 0.0353558
# 49g  : looking -0.1533704
# 49g  : solid 0.041618537
# 49g  : reliable -0.054735076
# 49g  : calculator 0.0152245425
# 49g  : hp12c -0.12930831
# 49g  : may 0.0067993854
# 49g  : programmable -0.017232902
# 49g  : basic -0.033711057
# 49g  : statistics -0.1830391
# 49g  : well 0.12311688
# 49g  : many -0.03577241
# 49g  : business -0.081469394
# 49g  : applications 0.1462838
# 49g  : manual 0.0011978501
# 49g  : makes 0.029490685
# 49g  : sense -0.13184506
# 49g  : running -0.14565367
# 49g  : short 0.16538942
# 49g  : orderim -0.2322013
# 49g  : ready -0.020647207
# 49g  : set -0.006262658
# 49g  : aside 0.03632761
# 49g  : move -0.08461311
# 49g  : back -0.100573495
# 49g  : old -0.09796074
# 49g  : friend -0.084705025
# 49g  : didnt -0.2193269
# 49g  : even 0.06279043
# 49g  : replace 0.027825532
# 49g  : batteries -0.04272527
# 49g  : well 0.12311688
# 49g  : decade -0.01402595
# 49g  : usehp -0.024415737
# 49g  : im -0.12983209
# 49g  : coming -0.004904611
# 49g  : home -0.053173847
# mistake  : served -0.10249275
# mistake  : travelling 0.09004017
# mistake  : searched 0.15902494
# mistake  : one -0.0833874
# mistake  : replace -0.16988334
# mistake  : one -0.0833874
# mistake  : purchased 0.03967479
# mistake  : people -0.07444483
# mistake  : view 0.07948484
# mistake  : powerful -0.03307532
# mistake  : using -0.02817364
# mistake  : sketchy -0.03402996
# mistake  : need 0.09039416
# mistake  : way 0.1300887
# mistake  : sense 0.08583147
# mistake  : solid 0.014816882
# mistake  : reliable 0.056943174
# mistake  : programmable 0.07302138
# mistake  : statistics 0.02493068
# mistake  : well 0.10661975
# mistake  : sense 0.08583147
# mistake  : running 0.054125544
# mistake  : short 0.06945558
# mistake  : orderim 0.027332718
# mistake  : ready -0.018599175
# mistake  : set 0.04514657
# mistake  : move -0.15513453
# mistake  : old -0.078852914
# mistake  : replace -0.16988334
# mistake  : well 0.10661975
# mistake  : usehp -0.12034438
# know  : served 0.1384418
# know  : lost 0.0125105325
# know  : travelling 0.06505142
# know  : searched -0.06876355
# know  : one -0.07542329
# know  : replace 0.1432992
# know  : one -0.07542329
# know  : purchased -0.0034492486
# know  : mistake -0.015570477
# know  : many 0.080767
# know  : people -0.12252667
# know  : view -0.09908316
# know  : line 0.1808964
# know  : may 0.02025259
# know  : powerful 0.22683509
# know  : using 0.08057425
# know  : manual 0.05123559
# know  : sketchy -0.0017819919
# know  : need 0.020110888
# know  : way 0.04911014
# know  : makes 0.013072086
# know  : sense -0.021862362
# know  : meif -0.079428814
# know  : looking 0.0011729441
# know  : solid 0.2500299
# know  : reliable 0.11276896
# know  : may 0.02025259
# know  : programmable -0.012593153
# know  : statistics 0.08253347
# know  : well -0.0009219914
# know  : many 0.080767
# know  : manual 0.05123559
# know  : makes 0.013072086
# know  : sense -0.021862362
# know  : running -0.025906952
# know  : short -0.014570698
# know  : orderim 0.12597372
# know  : ready 0.029752444
# know  : set -0.109224595
# know  : move 0.07732895
# know  : old -0.034480195
# know  : replace 0.1432992
# know  : well -0.0009219914
# know  : usehp 0.1705891
# many  : served 0.07317261
# many  : travelling -0.23261657
# many  : searched -0.0017264788
# many  : one -0.028475337
# many  : replace -0.06323039
# many  : one -0.028475337
# many  : purchased 0.024170738
# many  : mistake -0.1628273
# many  : people 0.11473704
# many  : view 0.3244359
# many  : may -0.077146545
# many  : powerful 0.054867584
# many  : using 0.048852336
# many  : sketchy 0.025833542
# many  : need -0.072501585
# many  : way -0.02839875
# many  : sense -0.10486298
# many  : meif 0.03900687
# many  : solid 0.053191807
# many  : reliable 0.16439894
# many  : may -0.077146545
# many  : programmable -0.0403127
# many  : statistics 0.13097543
# many  : well -0.22042786
# many  : sense -0.10486298
# many  : running 0.056465115
# many  : short -0.102572985
# many  : orderim -0.009512986
# many  : ready -0.006792548
# many  : set 0.00044895755
# many  : move 0.008603187
# many  : old 0.14272417
# many  : replace -0.06323039
# many  : well -0.22042786
# many  : usehp 0.09891037
# people  : served 0.0769606
# people  : travelling -0.07861371
# people  : searched 0.14375314
# people  : replace -0.075499944
# people  : purchased -0.03510316
# people  : view 0.24643941
# people  : powerful -0.12543042
# people  : using 0.13124718
# people  : sketchy -0.0051779025
# people  : way 0.10922163
# people  : sense 0.18268467
# people  : solid -0.002863794
# people  : reliable 0.03611505
# people  : programmable 0.0022094143
# people  : statistics -0.068557605
# people  : well -0.10058481
# people  : sense 0.18268467
# people  : running 0.0073971823
# people  : short -0.03934888
# people  : ready 0.022587823
# people  : set 0.05138237
# people  : replace -0.075499944
# people  : well -0.10058481
# people  : usehp 0.045511045
# view  : way -0.115647525
# view  : well -0.024209527
# view  : well -0.024209527
# hp  : hp12c -0.008879955
# hp  : served 0.08544172
# hp  : lost 0.13352613
# hp  : travelling 0.084382795
# hp  : searched -0.09823452
# hp  : one 0.1076088
# hp  : replace 0.022620272
# hp  : one 0.1076088
# hp  : purchased -0.03432066
# hp  : mistake -0.049593285
# hp  : know -0.09014127
# hp  : many 0.083381675
# hp  : people 0.0001655335
# hp  : view 0.194987
# hp  : line -0.17898433
# hp  : may -0.16258623
# hp  : powerful 0.16360411
# hp  : using -0.024117418
# hp  : manual -0.05510219
# hp  : sketchy -0.14434873
# hp  : need 0.06593702
# hp  : way -0.061705634
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : meif 0.110919
# hp  : looking 0.14833298
# hp  : solid -0.18124832
# hp  : reliable -0.0055697868
# hp  : hp12c -0.008879955
# hp  : may -0.16258623
# hp  : programmable -0.04159226
# hp  : statistics -0.12008675
# hp  : well 0.051083915
# hp  : many 0.083381675
# hp  : manual -0.05510219
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : running -0.058398593
# hp  : short -0.07616732
# hp  : orderim -0.009110292
# hp  : ready 0.018984461
# hp  : set -0.23088759
# hp  : move 0.024787236
# hp  : old 0.082955636
# hp  : replace 0.022620272
# hp  : well 0.051083915
# hp  : usehp 0.12764128
# hp  : im -0.006339741
# 49g  : bought 0.07399173
# 49g  : first -0.015214133
# 49g  : hp12c -0.12930831
# 49g  : served 0.0044194977
# 49g  : faithfully -0.2683381
# 49g  : lost 0.0113928225
# 49g  : travelling 0.10195126
# 49g  : searched -0.006931223
# 49g  : another -0.014278027
# 49g  : one 0.04712073
# 49g  : replace 0.027825532
# 49g  : found 0.022157108
# 49g  : one 0.04712073
# 49g  : difficult -0.06737784
# 49g  : come 0.04646948
# 49g  : area -0.08632576
# 49g  : decided 0.12307058
# 49g  : buy -0.19405155
# 49g  : purchased 0.10718884
# 49g  : hp -0.0489818
# 49g  : mistake 0.07722008
# 49g  : know 0.015188675
# 49g  : many -0.03577241
# 49g  : people 0.14722982
# 49g  : view 0.2315928
# 49g  : hp -0.0489818
# 49g  : 49g+ 0.028096301
# 49g  : flagship 0.024531052
# 49g  : hp -0.0489818
# 49g  : line -0.07527419
# 49g  : disasterthe 0.05984285
# 49g  : may 0.0067993854
# 49g  : powerful -0.03121867
# 49g  : using -0.064319
# 49g  : extremely 0.017212862
# 49g  : counterintuitiveand 0.080515094
# 49g  : manual 0.0011978501
# 49g  : sketchy -0.02019897
# 49g  : best 0.18098393
# 49g  : hand 0.08237483
# 49g  : need 0.10352261
# 49g  : way -0.08916335
# 49g  : makes 0.029490685
# 49g  : good -0.1504924
# 49g  : sense -0.13184506
# 49g  : meif 0.0353558
# 49g  : looking -0.1533704
# 49g  : solid 0.041618537
# 49g  : reliable -0.054735076
# 49g  : calculator 0.0152245425
# 49g  : hp12c -0.12930831
# 49g  : may 0.0067993854
# 49g  : programmable -0.017232902
# 49g  : basic -0.033711057
# 49g  : statistics -0.1830391
# 49g  : well 0.12311688
# 49g  : many -0.03577241
# 49g  : business -0.081469394
# 49g  : applications 0.1462838
# 49g  : manual 0.0011978501
# 49g  : makes 0.029490685
# 49g  : sense -0.13184506
# 49g  : running -0.14565367
# 49g  : short 0.16538942
# 49g  : orderim -0.2322013
# 49g  : ready -0.020647207
# 49g  : set -0.006262658
# 49g  : aside 0.03632761
# 49g  : move -0.08461311
# 49g  : back -0.100573495
# 49g  : old -0.09796074
# 49g  : friend -0.084705025
# 49g  : didnt -0.2193269
# 49g  : even 0.06279043
# 49g  : replace 0.027825532
# 49g  : batteries -0.04272527
# 49g  : well 0.12311688
# 49g  : decade -0.01402595
# 49g  : usehp -0.024415737
# 49g  : im -0.12983209
# 49g  : coming -0.004904611
# 49g  : home -0.053173847
# 49g+  : bought -0.13138294
# 49g+  : first 0.055107307
# 49g+  : hp12c -0.07483986
# 49g+  : served 0.07562739
# 49g+  : faithfully -0.18879034
# 49g+  : lost -0.16213062
# 49g+  : travelling 0.0043824534
# 49g+  : searched -0.15034129
# 49g+  : another 0.02480311
# 49g+  : one -0.018079927
# 49g+  : replace 0.18461429
# 49g+  : found -0.12818056
# 49g+  : one -0.018079927
# 49g+  : difficult 0.16569053
# 49g+  : come 0.15059131
# 49g+  : area -0.014315147
# 49g+  : decided 0.027328838
# 49g+  : buy -0.21328413
# 49g+  : purchased 0.0099123595
# 49g+  : hp 0.045227002
# 49g+  : mistake -0.03769143
# 49g+  : know 0.0023316299
# 49g+  : many -0.05100378
# 49g+  : people 0.11030165
# 49g+  : view -0.018337741
# 49g+  : hp 0.045227002
# 49g+  : flagship 0.27145007
# 49g+  : hp 0.045227002
# 49g+  : line 0.04534686
# 49g+  : disasterthe -0.09691902
# 49g+  : may -0.00012365356
# 49g+  : powerful 0.045569465
# 49g+  : using 0.008143528
# 49g+  : extremely 0.10158267
# 49g+  : counterintuitiveand -0.022547623
# 49g+  : manual -0.102896065
# 49g+  : sketchy 0.16474506
# 49g+  : best -0.055706397
# 49g+  : hand -0.011060687
# 49g+  : need 0.06550941
# 49g+  : way -0.03825076
# 49g+  : makes -0.045736033
# 49g+  : good 0.1455794
# 49g+  : sense -0.0005275889
# 49g+  : meif 0.10243563
# 49g+  : looking -0.045451045
# 49g+  : solid -0.08036434
# 49g+  : reliable -0.17736831
# 49g+  : calculator -0.079211295
# 49g+  : hp12c -0.07483986
# 49g+  : may -0.00012365356
# 49g+  : programmable 0.074941605
# 49g+  : basic 0.24599777
# 49g+  : statistics 0.024924485
# 49g+  : well -0.0921172
# 49g+  : many -0.05100378
# 49g+  : business 0.04777044
# 49g+  : applications 0.044792455
# 49g+  : manual -0.102896065
# 49g+  : makes -0.045736033
# 49g+  : sense -0.0005275889
# 49g+  : running -0.04229851
# 49g+  : short -0.06593454
# 49g+  : orderim -0.07104559
# 49g+  : ready -0.07384495
# 49g+  : set -0.1196658
# 49g+  : aside -0.090928696
# 49g+  : move 0.011696247
# 49g+  : back -0.27542418
# 49g+  : old 0.019861422
# 49g+  : friend 0.07084012
# 49g+  : didnt 0.0284853
# 49g+  : even 0.22714108
# 49g+  : replace 0.18461429
# 49g+  : batteries 0.053358864
# 49g+  : well -0.0921172
# 49g+  : decade 0.15311474
# 49g+  : usehp 0.055518765
# 49g+  : im 0.04420764
# 49g+  : coming -0.123283595
# 49g+  : home -0.032094724
# flagship  : hp12c -0.18741132
# flagship  : served -0.05565661
# flagship  : lost 0.1498722
# flagship  : travelling -0.03353717
# flagship  : searched -0.07189817
# flagship  : one 0.011015015
# flagship  : replace 0.15787564
# flagship  : found -0.026598664
# flagship  : one 0.011015015
# flagship  : purchased -0.0940694
# flagship  : hp 0.015536473
# flagship  : mistake 0.076146826
# flagship  : know 0.062493894
# flagship  : many -0.04996881
# flagship  : people 0.06446522
# flagship  : view -0.013082935
# flagship  : hp 0.015536473
# flagship  : hp 0.015536473
# flagship  : line 0.10851175
# flagship  : may 0.04859436
# flagship  : powerful -0.016282842
# flagship  : using 0.04995591
# flagship  : manual 0.014825333
# flagship  : sketchy -0.050347812
# flagship  : hand -0.040714707
# flagship  : need 0.035854686
# flagship  : way -0.025413873
# flagship  : makes 0.047995426
# flagship  : good 0.04873293
# flagship  : sense -0.017681193
# flagship  : meif -0.03234339
# flagship  : looking -0.21888049
# flagship  : solid -0.06184947
# flagship  : reliable 0.05479342
# flagship  : hp12c -0.18741132
# flagship  : may 0.04859436
# flagship  : programmable 0.1195167
# flagship  : statistics -0.05410088
# flagship  : well 9.155446e-05
# flagship  : many -0.04996881
# flagship  : manual 0.014825333
# flagship  : makes 0.047995426
# flagship  : sense -0.017681193
# flagship  : running -0.07040583
# flagship  : short 0.19160405
# flagship  : orderim -0.004246178
# flagship  : ready -0.06855457
# flagship  : set -0.026851645
# flagship  : move 0.11507968
# flagship  : old 0.0011030892
# flagship  : friend 0.0581325
# flagship  : replace 0.15787564
# flagship  : well 9.155446e-05
# flagship  : usehp 0.044435706
# flagship  : im -0.017270474
# flagship  : home 0.15328856
# hp  : hp12c -0.008879955
# hp  : served 0.08544172
# hp  : lost 0.13352613
# hp  : travelling 0.084382795
# hp  : searched -0.09823452
# hp  : one 0.1076088
# hp  : replace 0.022620272
# hp  : one 0.1076088
# hp  : purchased -0.03432066
# hp  : mistake -0.049593285
# hp  : know -0.09014127
# hp  : many 0.083381675
# hp  : people 0.0001655335
# hp  : view 0.194987
# hp  : line -0.17898433
# hp  : may -0.16258623
# hp  : powerful 0.16360411
# hp  : using -0.024117418
# hp  : manual -0.05510219
# hp  : sketchy -0.14434873
# hp  : need 0.06593702
# hp  : way -0.061705634
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : meif 0.110919
# hp  : looking 0.14833298
# hp  : solid -0.18124832
# hp  : reliable -0.0055697868
# hp  : hp12c -0.008879955
# hp  : may -0.16258623
# hp  : programmable -0.04159226
# hp  : statistics -0.12008675
# hp  : well 0.051083915
# hp  : many 0.083381675
# hp  : manual -0.05510219
# hp  : makes -0.10320104
# hp  : sense 0.15204209
# hp  : running -0.058398593
# hp  : short -0.07616732
# hp  : orderim -0.009110292
# hp  : ready 0.018984461
# hp  : set -0.23088759
# hp  : move 0.024787236
# hp  : old 0.082955636
# hp  : replace 0.022620272
# hp  : well 0.051083915
# hp  : usehp 0.12764128
# hp  : im -0.006339741
# line  : served 0.10672861
# line  : lost -0.046295382
# line  : travelling 0.0642442
# line  : searched 0.16472645
# line  : one -0.17307511
# line  : replace -0.046133637
# line  : one -0.17307511
# line  : purchased 0.051335312
# line  : mistake -0.01759426
# line  : many -0.25066587
# line  : people -0.10311952
# line  : view -0.19153687
# line  : may 0.115968555
# line  : powerful 0.053933974
# line  : using -0.054603107
# line  : manual 0.15471973
# line  : sketchy 0.115342885
# line  : need 0.105635956
# line  : way -0.11247894
# line  : makes 0.1313795
# line  : sense -0.011902953
# line  : meif -0.11391874
# line  : looking -0.132828
# line  : solid 0.16194491
# line  : reliable -0.003981768
# line  : may 0.115968555
# line  : programmable 0.034631543
# line  : statistics 0.115079224
# line  : well -0.120477125
# line  : many -0.25066587
# line  : manual 0.15471973
# line  : makes 0.1313795
# line  : sense -0.011902953
# line  : running 0.036510758
# line  : short 0.02855632
# line  : orderim 0.101510726
# line  : ready 0.05680326
# line  : set 0.0033033188
# line  : move 0.23289187
# line  : old -0.025753
# line  : replace -0.046133637
# line  : well -0.120477125
# line  : usehp 0.072647065
# disasterthe  : first -0.034717076
# disasterthe  : hp12c -0.025748214
# disasterthe  : served -0.084090464
# disasterthe  : faithfully -0.042249724
# disasterthe  : lost 0.070449226
# disasterthe  : travelling 0.070680246
# disasterthe  : searched 0.09934863
# disasterthe  : one -0.024006553
# disasterthe  : replace 0.014972283
# disasterthe  : found -0.21938571
# disasterthe  : one -0.024006553
# disasterthe  : purchased -0.02253978
# disasterthe  : hp 0.004275182
# disasterthe  : mistake 0.12142083
# disasterthe  : know 0.06637579
# disasterthe  : many 0.054685805
# disasterthe  : people 0.046553247
# disasterthe  : view -0.028394924
# disasterthe  : hp 0.004275182
# disasterthe  : flagship 0.110659115
# disasterthe  : hp 0.004275182
# disasterthe  : line -0.0850571
# disasterthe  : may 0.02759057
# disasterthe  : powerful -0.10537249
# disasterthe  : using 0.15010105
# disasterthe  : extremely 0.13460721
# disasterthe  : manual 0.02702684
# disasterthe  : sketchy -0.07520716
# disasterthe  : hand -0.09585089
# disasterthe  : need 0.12406883
# disasterthe  : way -0.0041541904
# disasterthe  : makes 0.00615536
# disasterthe  : good 0.017246809
# disasterthe  : sense -0.043932483
# disasterthe  : meif -0.061256196
# disasterthe  : looking -0.13460316
# disasterthe  : solid -0.102598004
# disasterthe  : reliable 0.025571147
# disasterthe  : hp12c -0.025748214
# disasterthe  : may 0.02759057
# disasterthe  : programmable 0.04050327
# disasterthe  : statistics -0.15574497
# disasterthe  : well -0.019841637
# disasterthe  : many 0.054685805
# disasterthe  : manual 0.02702684
# disasterthe  : makes 0.00615536
# disasterthe  : sense -0.043932483
# disasterthe  : running 0.041877523
# disasterthe  : short 0.333552
# disasterthe  : orderim 0.085078724
# ...
# friend  : purchased 0.0257442
# friend  : hp 0.14025578
# friend  : mistake 0.08771479
# friend  : know 0.118338995
# friend  : many -0.0123715075
# friend  : people -0.028164053
# friend  : view -0.009078852
# friend  : hp 0.14025578
# friend  : hp 0.14025578
# friend  : line -0.122117564
# friend  : may 0.22415495
# friend  : powerful 0.041655805
# friend  : using 0.050702345
# friend  : manual -0.107414864
# friend  : sketchy -0.03726656
# friend  : hand 0.07357758
# friend  : need -0.040760357
# friend  : way 0.11576417
# friend  : makes 0.036158048
# friend  : good 0.12743723
# friend  : sense -0.009249104
# friend  : meif 0.20163275
# friend  : looking 0.19193879
# friend  : solid -0.098634906
# friend  : reliable -0.15853134
# friend  : hp12c 0.1202203
# friend  : may 0.22415495
# friend  : programmable 0.26298454
# friend  : statistics 0.10251414
# friend  : well 0.09862228
# friend  : many -0.0123715075
# friend  : manual -0.107414864
# friend  : makes 0.036158048
# friend  : sense -0.009249104
# friend  : running 0.09084673
# friend  : short -0.10948797
# friend  : orderim 0.08357533
# friend  : ready 0.1616833
# friend  : set -0.09069106
# friend  : move 0.10476795
# friend  : old -0.08155276
# friend  : replace 0.055471763
# friend  : well 0.09862228
# friend  : usehp 0.06635664
# friend  : im 0.020388918
# friend  : home -0.03343477
# didnt  : first -0.052788064
# didnt  : hp12c -0.06278124
# didnt  : served -0.0401181
# didnt  : faithfully 0.0090459455
# didnt  : lost 0.010403484
# didnt  : travelling -0.15495151
# didnt  : searched 0.12197395
# didnt  : one 0.03593893
# didnt  : replace -0.05675383
# didnt  : found -0.0074393055
# didnt  : one 0.03593893
# didnt  : difficult -0.13747512
# didnt  : purchased -0.031083724
# didnt  : hp -0.015389471
# didnt  : mistake -0.056681793
# didnt  : know 0.0022512933
# didnt  : many 0.041473977
# didnt  : people -0.077748336
# didnt  : view -0.088826135
# didnt  : hp -0.015389471
# didnt  : flagship 0.03463162
# didnt  : hp -0.015389471
# didnt  : line 0.045174062
# didnt  : disasterthe -0.115521505
# didnt  : may -0.041427486
# didnt  : powerful 0.13465677
# didnt  : using -0.08758155
# didnt  : extremely -0.16124672
# didnt  : manual 0.07148892
# didnt  : sketchy -0.049185254
# didnt  : hand 0.040082052
# didnt  : need -0.13742886
# didnt  : way 0.0867123
# didnt  : makes 0.02125551
# didnt  : good 0.0528549
# didnt  : sense 0.006795621
# didnt  : meif -0.033011835
# didnt  : looking 0.09775232
# didnt  : solid -0.03644082
# didnt  : reliable 0.05641994
# didnt  : hp12c -0.06278124
# didnt  : may -0.041427486
# didnt  : programmable -0.119657815
# didnt  : statistics -0.029161556
# didnt  : well -0.033788852
# didnt  : many 0.041473977
# didnt  : manual 0.07148892
# didnt  : makes 0.02125551
# didnt  : sense 0.006795621
# didnt  : running 0.14173631
# didnt  : short 0.11148536
# didnt  : orderim 0.06563451
# didnt  : ready 0.12558742
# didnt  : set -0.33716944
# didnt  : move -0.060787715
# didnt  : old 0.022325812
# didnt  : friend -0.045368392
# didnt  : even 0.061056875
# didnt  : replace -0.05675383
# didnt  : well -0.033788852
# didnt  : usehp 0.12841219
# didnt  : im -0.019490134
# didnt  : home -0.061550308
# even  : first 0.090411186
# even  : hp12c 0.08557705
# even  : served -0.09536722
# even  : faithfully -0.0146489
# even  : lost -0.030839533
# even  : travelling 0.21399754
# even  : searched -0.1962837
# even  : one -0.056963805
# even  : replace -0.07852195
# even  : found -0.060444158
# even  : one -0.056963805
# even  : purchased 0.045237623
# even  : hp -0.030372843
# even  : mistake 0.037365228
# even  : know 0.013975682
# even  : many -0.1274918
# even  : people -0.022997554
# even  : view -0.09351941
# even  : hp -0.030372843
# even  : flagship 0.015607698
# even  : hp -0.030372843
# even  : line -0.05863714
# even  : may -0.06632992
# even  : powerful 0.10148294
# even  : using -0.09225991
# even  : extremely -0.096343756
# even  : manual 0.12966375
# even  : sketchy 0.04939592
# even  : hand 0.10158641
# even  : need -0.06269597
# even  : way 0.14268202
# even  : makes -0.0058717215
# even  : good 0.04945401
# even  : sense 0.031333413
# even  : meif 0.13586153
# even  : looking -0.0016738223
# even  : solid -0.035697464
# even  : reliable -0.11142127
# even  : hp12c 0.08557705
# even  : may -0.06632992
# even  : programmable 0.060590375
# even  : statistics -0.1666053
# even  : well -0.035680577
# even  : many -0.1274918
# even  : manual 0.12966375
# even  : makes -0.0058717215
# even  : sense 0.031333413
# even  : running -0.088217326
# even  : short 0.28043467
# even  : orderim 0.0006149686
# even  : ready -0.051041584
# even  : set -0.1060067
# even  : move -0.07468359
# even  : old -0.1126072
# even  : friend 0.07609102
# even  : replace -0.07852195
# even  : well -0.035680577
# even  : usehp 0.008089409
# even  : im 0.04428973
# even  : home -0.30360347
# replace  : served 0.08113701
# replace  : travelling 0.04663511
# replace  : searched -0.12527125
# replace  : view -0.058068126
# replace  : using 0.021536885
# replace  : sketchy -0.03830632
# replace  : way 0.06584009
# replace  : sense -0.1963105
# replace  : solid 0.18227406
# replace  : statistics 0.0025862302
# replace  : well -0.025098061
# replace  : sense -0.1963105
# replace  : running -0.074493244
# replace  : short -0.10535399
# replace  : set -0.2971191
# replace  : well -0.025098061
# replace  : usehp 0.052261826
# batteries  : bought -0.107917204
# batteries  : first 0.10690725
# batteries  : hp12c 0.028314974
# batteries  : served 0.08558815
# batteries  : faithfully -0.19296375
# batteries  : lost -0.052151706
# batteries  : travelling 0.028807838
# batteries  : searched 0.014727943
# batteries  : one 0.008415268
# batteries  : replace -0.060246143
# batteries  : found 0.067062914
# batteries  : one 0.008415268
# batteries  : difficult 0.19242507
# batteries  : come 0.018341208
# batteries  : decided 0.21149907
# batteries  : buy -0.047906764
# batteries  : purchased 0.053296205
# batteries  : hp 0.10062956
# batteries  : mistake -0.040257562
# batteries  : know -0.060986448
# batteries  : many 0.079848155
# batteries  : people -0.06276686
# batteries  : view 0.08401683
# batteries  : hp 0.10062956
# batteries  : flagship 0.0057065585
# batteries  : hp 0.10062956
# batteries  : line 0.056475956
# batteries  : disasterthe 0.020744463
# batteries  : may 0.02992329
# batteries  : powerful 0.048357453
# batteries  : using -0.010562379
# batteries  : extremely -0.18583897
# batteries  : counterintuitiveand 0.18758279
# batteries  : manual 0.029254824
# batteries  : sketchy -0.08539123
# batteries  : best -0.026185341
# batteries  : hand -0.03325125
# batteries  : need 0.04794505
# batteries  : way 0.06473115
# batteries  : makes 0.021898516
# batteries  : good 0.00797694
# batteries  : sense -0.010714399
# batteries  : meif 0.1133871
# batteries  : looking 0.08096597
# batteries  : solid 0.07996108
# batteries  : reliable -0.12760246
# batteries  : calculator 0.16288045
# batteries  : hp12c 0.028314974
# batteries  : may 0.02992329
# batteries  : programmable 0.048873343
# batteries  : statistics 0.001296161
# batteries  : well -0.16643606
# batteries  : many 0.079848155
# batteries  : business -0.10110536
# batteries  : manual 0.029254824
# batteries  : makes 0.021898516
# batteries  : sense -0.010714399
# batteries  : running -0.00021667138
# batteries  : short -0.07218417
# batteries  : orderim -0.16632526
# batteries  : ready -0.06388398
# batteries  : set 0.05593574
# batteries  : move -0.13968931
# batteries  : old -0.03959981
# batteries  : friend 0.10351682
# batteries  : didnt -0.022394018
# batteries  : even 0.05819934
# batteries  : replace -0.060246143
# batteries  : well -0.16643606
# batteries  : decade 0.1193053
# batteries  : usehp 0.021863604
# batteries  : im -0.109605365
# batteries  : coming 0.20634405
# batteries  : home -0.092385724
# decade  : first -0.05294987
# decade  : hp12c -0.118598975
# decade  : served -0.15026633
# decade  : faithfully -0.24572118
# decade  : lost 0.177586
# decade  : travelling -0.021675522
# decade  : searched -0.06521253
# decade  : one -0.017695904
# decade  : replace -0.26211455
# decade  : found -0.021182615
# decade  : one -0.017695904
# decade  : difficult -0.021492882
# decade  : decided 0.17807536
# decade  : purchased 0.08087105
# decade  : hp 0.050721385
# decade  : mistake 0.09334698
# decade  : know -0.08049103
# decade  : many 0.035148714
# decade  : people 0.037008673
# decade  : view 0.023583965
# decade  : hp 0.050721385
# decade  : flagship 0.17228894
# decade  : hp 0.050721385
# decade  : line -0.08279896
# decade  : disasterthe 0.144262
# decade  : may -0.080419965
# decade  : powerful 0.16054872
# decade  : using 0.04057055
# decade  : extremely -0.039483428
# decade  : manual -0.15101407
# decade  : sketchy -0.010945469
# decade  : hand -0.079851516
# decade  : need 0.070886575
# decade  : way -0.14988713
# decade  : makes -0.12834938
# decade  : good -0.063287884
# decade  : sense 0.06382102
# decade  : meif -0.11915469
# decade  : looking -0.04868688
# decade  : solid -0.20500363
# decade  : reliable 0.0014076666
# decade  : hp12c -0.118598975
# decade  : may -0.080419965
# decade  : programmable 0.10351138
# decade  : statistics 0.0879098
# decade  : well 0.066539414
# decade  : many 0.035148714
# decade  : manual -0.15101407
# decade  : makes -0.12834938
# decade  : sense 0.06382102
# decade  : running 0.019293487
# decade  : short 0.124372415
# decade  : orderim -0.0766511
# decade  : ready -0.020471996
# decade  : set 0.16065055
# decade  : move 0.00017675012
# decade  : old 0.08140947
# decade  : friend -0.0069058496
# decade  : didnt 0.14137277
# decade  : even 0.08793324
# decade  : replace -0.26211455
# decade  : well 0.066539414
# decade  : usehp -0.1589366
# decade  : im -0.068576686
# decade  : home 0.110930115
# usehp  : view 0.020571893
# usehp  : using 0.0723968
# usehp  : way 0.05271339
# usehp  : well -0.11368419
# usehp  : well -0.11368419
# 12c  : bought 0.12621449
# 12c  : first -0.005404008
# 12c  : hp12c 0.021667156
# 12c  : 1984 -0.021768307
# 12c  : served -0.17694727
# 12c  : faithfully 0.063363574
# 12c  : 2002 0.116405815
# 12c  : lost -0.07511242
# 12c  : travelling -0.04210868
# 12c  : searched -0.025573839
# 12c  : another 0.013888652
# 12c  : one -0.03227813
# 12c  : replace 0.027399736
# 12c  : found 0.008485555
# 12c  : one -0.03227813
# 12c  : difficult -0.02113394
# 12c  : come -0.14896792
# 12c  : area 0.15093787
# 12c  : decided 0.024937643
# 12c  : buy -0.01607673
# 12c  : purchased -0.08803645
# 12c  : hp -0.010247061
# 12c  : 49g 0.07297887
# 12c  : mistake 0.038955726
# 12c  : know -0.05584488
# 12c  : many -0.095436715
# 12c  : people 0.18453595
# 12c  : view -0.07868151
# 12c  : hp -0.010247061
# 12c  : 49g 0.07297887
# 12c  : 49g+ 0.09659587
# 12c  : flagship 0.033373233
# 12c  : hp -0.010247061
# 12c  : line -0.047259822
# 12c  : disasterthe 0.15711181
# 12c  : 49g 0.07297887
# 12c  : may -0.017977886
# 12c  : powerful -0.052322835
# 12c  : using 0.18115532
# 12c  : extremely -0.07257827
# 12c  : counterintuitiveand -0.058028925
# 12c  : manual -0.031184573
# 12c  : sketchy 0.060256954
# 12c  : best 0.03343821
# 12c  : hand -0.0480034
# 12c  : need -0.018145159
# 12c  : way 0.017980028
# 12c  : makes -0.033229906
# 12c  : good -0.04703371
# 12c  : sense 0.19018735
# 12c  : meif -0.17401786
# 12c  : looking 0.014875385
# 12c  : solid -0.16801853
# 12c  : reliable 0.04982856
# 12c  : calculator -0.0012150656
# 12c  : hp12c 0.021667156
# 12c  : may -0.017977886
# 12c  : programmable 0.08570013
# 12c  : basic 0.01979277
# 12c  : statistics 0.06282969
# 12c  : well -0.07968187
# 12c  : many -0.095436715
# 12c  : business 0.11711094
# 12c  : applications -0.027091853
# 12c  : manual -0.031184573
# 12c  : makes -0.033229906
# 12c  : sense 0.19018735
# 12c  : running -0.024062429
# 12c  : short 0.054361895
# 12c  : orderim -0.023122799
# 12c  : ready -0.13093224
# 12c  : set 0.101113625
# 12c  : 49g 0.07297887
# 12c  : aside -0.1252446
# 12c  : move -0.12201692
# 12c  : back -0.03130778
# 12c  : old -0.046591673
# 12c  : friend -0.09636161
# 12c  : didnt -0.09173699
# 12c  : even 0.054164894
# 12c  : replace 0.027399736
# 12c  : batteries 0.017242277
# 12c  : well -0.07968187
# 12c  : decade 0.18936658
# 12c  : usehp -0.115534686
# 12c  : im -0.06801314
# 12c  : coming 0.001099211
# 12c  : home 0.047871806
# im  : served 0.36565134
# im  : lost 0.018519463
# im  : travelling -0.0067704474
# im  : searched 0.09961678
# im  : one -0.12448573
# im  : replace 0.02387082
# im  : one -0.12448573
# im  : purchased 0.0008343302
# im  : mistake 0.035565555
# im  : know 0.11152442
# im  : many 0.020546528
# im  : people 0.041280415
# im  : view -0.056786258
# im  : line 0.030654147
# im  : may -0.060975518
# im  : powerful -0.029108007
# im  : using 0.036504406
# im  : manual -0.18270977
# im  : sketchy -0.0790808
# im  : need -0.032018423
# im  : way 0.09135938
# im  : makes -0.13094991
# im  : sense 0.02253015
# im  : meif -0.05070135
# im  : looking 0.06226777
# im  : solid 0.18725902
# im  : reliable 0.15765105
# im  : may -0.060975518
# im  : programmable 0.08570018
# im  : statistics 0.079241596
# im  : well 0.071107574
# im  : many 0.020546528
# im  : manual -0.18270977
# im  : makes -0.13094991
# im  : sense 0.02253015
# im  : running 0.02802085
# im  : short -0.0783744
# im  : orderim -0.0016368004
# im  : ready 0.09258611
# im  : set -0.04505863
# im  : move -0.08957193
# im  : old 0.005293549
# im  : replace 0.02387082
# im  : well 0.071107574
# im  : usehp 0.100182265
# coming  : first 0.03941055
# coming  : hp12c 0.17912056
# coming  : served 0.04996658
# coming  : faithfully 0.07765741
# coming  : lost -0.10985842
# coming  : travelling 0.0707703
# coming  : searched 0.22209212
# coming  : one 0.08599077
# coming  : replace -0.28102636
# coming  : found 0.068205565
# coming  : one 0.08599077
# coming  : difficult 0.0588283
# coming  : decided 0.20092526
# coming  : purchased 0.19322418
# coming  : hp 0.03341151
# coming  : mistake 0.17908224
# coming  : know -0.081365
# coming  : many -0.14424306
# coming  : people -0.0614681
# coming  : view 0.060049556
# coming  : hp 0.03341151
# coming  : flagship -0.09877508
# coming  : hp 0.03341151
# coming  : line 0.19003041
# coming  : disasterthe 0.02703035
# coming  : may 0.083826296
# coming  : powerful 0.08211235
# coming  : using 0.058548164
# coming  : extremely -0.14011443
# coming  : counterintuitiveand 0.024576623
# coming  : manual 0.15405628
# coming  : sketchy -0.09958613
# coming  : hand -0.030779555
# coming  : need 0.15314566
# coming  : way 0.00987865
# coming  : makes 0.0856522
# coming  : good -0.318045
# coming  : sense 0.14458828
# coming  : meif 0.13947023
# coming  : looking 0.051716857
# coming  : solid -0.06057709
# coming  : reliable 0.042720802
# coming  : hp12c 0.17912056
# coming  : may 0.083826296
# coming  : programmable 0.055340566
# coming  : statistics 0.040390663
# coming  : well -0.08473017
# coming  : many -0.14424306
# coming  : manual 0.15405628
# coming  : makes 0.0856522
# coming  : sense 0.14458828
# coming  : running 0.11665671
# coming  : short -0.03814377
# coming  : orderim -0.035602033
# coming  : ready -0.011465999
# coming  : set 0.1653979
# coming  : move 0.0107078105
# coming  : old 0.052117612
# coming  : friend 0.0605118
# coming  : didnt -0.0732039
# coming  : even -0.06082301
# coming  : replace -0.28102636
# coming  : well -0.08473017
# coming  : decade -0.050910838
# coming  : usehp 0.081503734
# coming  : im -0.019426927
# coming  : home 0.016344745
# home  : hp12c -0.052266117
# home  : served -0.03394238
# home  : lost 0.035839267
# home  : travelling 0.005406431
# home  : searched 0.121036574
# home  : one 0.03190763
# home  : replace 0.08092719
# home  : one 0.03190763
# home  : purchased -0.21720128
# home  : hp -0.0061716842
# home  : mistake 0.08000727
# home  : know -0.092094675
# home  : many 0.0734542
# home  : people 0.2417528
# home  : view 0.22484232
# home  : hp -0.0061716842
# home  : hp -0.0061716842
# home  : line -0.05057563
# home  : may 0.06954522
# home  : powerful -0.07083443
# home  : using 0.15387177
# home  : manual -0.040139947
# home  : sketchy -0.10948725
# home  : need -0.052296694
# home  : way -0.11386736
# home  : makes -0.05510898
# home  : sense 0.013019536
# home  : meif 0.024037056
# home  : looking -0.0013599223
# home  : solid 0.0007400932
# home  : reliable -0.005556943
# home  : hp12c -0.052266117
# home  : may 0.06954522
# home  : programmable -0.008772935
# home  : statistics 0.15094894
# home  : well 0.03341939
# home  : many 0.0734542
# home  : manual -0.040139947
# home  : makes -0.05510898
# home  : sense 0.013019536
# home  : running -0.14916159
# home  : short -0.06129026
# home  : orderim 0.027507203
# home  : ready 0.0025634705
# home  : set 0.1674426
# home  : move -0.117138565
# home  : old -0.13921387
# home  : replace 0.08092719
# home  : well 0.03341939
# home  : usehp 0.110057324
# home  : im 0.003920035
